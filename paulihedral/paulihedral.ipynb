# %%
from benchmark.mypauli import *
from parallel_bl import *
from tools import *
from qiskit import transpile
import time
import synthesis_FT
ctime = time.time
parr = [[pauliString('XXXII', 1.0),pauliString('XXIII', 1.0)],[pauliString('XXIXI', 1.0),pauliString('XXIIX', 1.0)]]
nq = len(parr[0][0])
length = nq//2 # `length' is a hyperparameter, and can be adjusted for best performance
t0 = ctime()
a1 = depth_oriented_scheduling(parr, length=length, maxiter=30)
qc = synthesis_FT.block_opt_FT(a1)
print('PH, Time costed:', ctime()-t0, flush=True)
t0 = ctime()
qc2 = transpile(qc, basis_gates=['u3', 'cx'], optimization_level=3)
print_qc(qc2)
qc = synthesis_FT.qiskit_synthesis(a1)
print('Qiskit, Time costed:', ctime()-t0, flush=True)
t0 = ctime()
qc2 = transpile(qc, basis_gates=['u3', 'cx'], optimization_level=3)
print_qc(qc2)
# Out:
# PH, Time costed: 0.0006611347198486328
# CNOT: 6, Single: 10, Total: 16, Depth: 10
# Qiskit, Time costed: 0.15702390670776367
# CNOT: 8, Single: 14, Total: 22, Depth: 14
# (8, 14, 14)

# %%
# %run table2.py

# %%
# %run table3.py

# %%
# %run table4.py
# Out:
# UCCSD: 8
# DO + Block: CNOT: 1165, Single: 663, Total: 1828, Depth: 1396
# GCO + Block: CNOT: 1219, Single: 684, Total: 1903, Depth: 1394
# DO + Qiskit: CNOT: 2638, Single: 1418, Total: 4056, Depth: 2415
# GCO + Qiskit: CNOT: 2664, Single: 1439, Total: 4103, Depth: 2426
# DO vs GCO CNOT: -4.43%, Single: -3.07%, Total: -3.94%, Depth: 0.14%
# Block-Wise Compilation vs Qiskit
# CNOT: -55.84%, Single: -53.24%, Total: -54.93%, Depth: -42.19%
# UCCSD: 12
# DO + Block: CNOT: 17322, Single: 8673, Total: 25995, Depth: 17856
# GCO + Block: CNOT: 16292, Single: 9462, Total: 25754, Depth: 17389
# DO + Qiskit: CNOT: 35937, Single: 15070, Total: 51007, Depth: 30726
# GCO + Qiskit: CNOT: 41771, Single: 17636, Total: 59407, Depth: 35515
# DO vs GCO CNOT: 6.32%, Single: -8.34%, Total: 0.94%, Depth: 2.69%
# Block-Wise Compilation vs Qiskit
# CNOT: -51.80%, Single: -42.45%, Total: -49.04%, Depth: -41.89%
# QAOA, Seeds= [83, 193]
# Regular graph: [4, 20] Seed: 83
# DO + Block: CNOT: 346, Single: 95, Total: 441, Depth: 129
# GCO + Block: CNOT: 346, Single: 95, Total: 441, Depth: 129
# DO + Qiskit: CNOT: 405, Single: 117, Total: 522, Depth: 116
# GCO + Qiskit: CNOT: 398, Single: 102, Total: 500, Depth: 111
# DO vs GCO CNOT: 0.00%, Single: 0.00%, Total: 0.00%, Depth: 0.00%
# Block-Wise Compilation vs Qiskit
# CNOT:
# DO vs GCO CNOT: 0.00%, Single: 0.00%, Total: 0.00%, Depth: 0.00%
# Block-Wise Compilation vs Qiskit
# CNOT: -49.02%, Single: -14.41%, Total: -39.63%, Depth: 8.35%
# TSP: 5 Seed: 193
# DO + Block: CNOT: 1093, Single: 683, Total: 1776, Depth: 636
# GCO + Block: CNOT: 1093, Single: 683, Total: 1776, Depth: 636
# DO + Qiskit: CNOT: 1991, Single: 649, Total: 2640, Depth: 572
# GCO + Qiskit: CNOT: 1803, Single: 839, Total: 2642, Depth: 615
# DO vs GCO CNOT: 0.00%, Single: 0.00%, Total: 0.00%, Depth: 0.00%
# Block-Wise Compilation vs Qiskit
# CNOT: -45.10%, Single: 5.24%, Total: -32.73%, Depth: 11.19%
# Molecule: N2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Desktop/Workspace/Paulihedral_new/table4.py in <module>
#     166     print('Molecule:', moles[i])
#     167     parr = load_oplist(moles[i], benchmark='molecule')
# --> 168     PH(parr)
#     169
#     170 ############################
#
# ~/Desktop/Workspace/Paulihedral_new/table4.py in PH(parr)
#     116     # print('DO + Block, Time costed:', ctime()-t0, flush=True)
#     117     t0 = ctime()
# --> 118     qc2 = transpile(qc, basis_gates=['u3', 'cx'], optimization_level=3)
#     119     c0, s0, d0 = print_qc(qc2, None)
#     120     print('DO + Block:', end=" ")
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/compiler/transpile.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     241
#     242     # Transpile circuits in parallel
# --> 243     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#     244
#     245     end_time = time()
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/tools/parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     104         return []
#     105     if len(values) == 1:
# --> 106         return [task(values[0], *task_args, **task_kwargs)]
#     107
#     108     Publisher().publish("terra.parallel.start", len(values))
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/compiler/transpile.py in _transpile_circuit(circuit_config_tuple)
#     324         raise TranspilerError("optimization_level can range from 0 to 3.")
#     325
# --> 326     result = pass_manager.run(circuit, callback=transpile_config['callback'],
#     327                               output_name=transpile_config['output_name'])
#     328
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/transpiler/passmanager.py in run(self, circuits, output_name, callback)
#     223         """
#     224         if isinstance(circuits, QuantumCircuit):
# --> 225             return self._run_single_circuit(circuits, output_name, callback)
#     226         elif len(circuits) == 1:
#     227             return self._run_single_circuit(circuits[0], output_name, callback)
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/transpiler/passmanager.py in _run_single_circuit(self, circuit, output_name, callback)
#     286         if callback is None and self.callback:  # TODO to remove with __init__(callback)
#     287             callback = self.callback
# --> 288         result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     289         self.property_set = running_passmanager.property_set
#     290         return result
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py in run(***failed resolving arguments***)
#     111         for passset in self.working_list:
#     112             for pass_ in passset:
# --> 113                 dag = self._do_pass(pass_, dag, passset.options)
#     114
#     115         circuit = dag_to_circuit(dag)
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py in _do_pass(self, pass_, dag, options)
#     142         # Run the pass itself, if not already run
#     143         if pass_ not in self.valid_passes:
# --> 144             dag = self._run_this_pass(pass_, dag)
#     145
#     146             # update the valid_passes property
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py in _run_this_pass(self, pass_, dag)
#     154             # Measure time if we have a callback or logging set
#     155             start_time = time()
# --> 156             new_dag = pass_.run(dag)
#     157             end_time = time()
#     158             run_time = end_time - start_time
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/transpiler/passes/optimization/consolidate_blocks.py in run(self, dag)
#     140                         basis_count += 1
#     141                     subcirc.append(nd.op, [q[block_index_map[i]] for i in nd.qargs])
# --> 142                 unitary = UnitaryGate(Operator(subcirc))  # simulates the circuit
#     143
#     144                 max_2q_depth = 20  # If depth > 20, there will be 1q gates to consolidate.
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py in __init__(self, data, input_dims, output_dims)
#      82             # conditional gates, measure, or reset will cause an
#      83             # exception to be raised.
# ---> 84             self._data = self._init_instruction(data).data
#      85         elif hasattr(data, 'to_operator'):
#      86             # If the data object has a 'to_operator' attribute this is given
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py in _init_instruction(cls, instruction)
#     490         if isinstance(instruction, QuantumCircuit):
#     491             instruction = instruction.to_instruction()
# --> 492         op._append_instruction(instruction)
#     493         return op
#     494
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py in _append_instruction(self, obj, qargs)
#     537                     qargs=qargs)
#     538                 self._data = op.data
# --> 539             flat_instr = obj.definition.to_instruction()
#     540             for instr, qregs, cregs in flat_instr.definition.data:
#     541                 if cregs:
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py in to_instruction(self, parameter_map)
#     970         """
#     971         from qiskit.converters.circuit_to_instruction import circuit_to_instruction
# --> 972         return circuit_to_instruction(self, parameter_map)
#     973
#     974     def to_gate(self, parameter_map=None, label=None):
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/converters/circuit_to_instruction.py in circuit_to_instruction(circuit, parameter_map, equivalence_library)
#     123     qc = QuantumCircuit(*regs, name=instruction.name)
#     124     for instr, qargs, cargs in definition:
# --> 125         qc._append(instr, qargs, cargs)
#     126     if circuit.global_phase:
#     127         qc.global_phase = circuit.global_phase
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py in _append(self, instruction, qargs, cargs)
#     861
#     862         # do some compatibility checks
# --> 863         self._check_dups(qargs)
#     864         self._check_qargs(qargs)
#     865         self._check_cargs(cargs)
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py in _check_dups(self, qubits)
#     938     def _check_dups(self, qubits):
#     939         """Raise exception if list of qubits contains duplicates."""
# --> 940         squbits = set(qubits)
#     941         if len(squbits) != len(qubits):
#     942             raise CircuitError("duplicate qubit arguments")
#
# ~/opt/anaconda3/envs/ASPLOS-AE/lib/python3.8/site-packages/qiskit/circuit/bit.py in __hash__(self)
#      71         return "%s(%s, %s)" % (self.__class__.__name__, self._register, self._index)
#      72
# ---> 73     def __hash__(self):
#      74         return self._hash
#      75
#
# KeyboardInterrupt:
